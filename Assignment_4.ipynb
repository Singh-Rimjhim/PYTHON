# %%
import numpy as np
import pandas as pd

# %%
#ques1
n1=int(input("enter 1st number"))
n2=int(input("enter 2nd number"))
print(n1-n2)
print(n1+n2)
print(n1*n2)
print(n1/n2)
print(n1//n2)
print(n1**n2)
print(n1%n2)
# Out:
# -1
# 3
# 2
# 0.5
# 0
# 1
# 1

# %%
#ques2
n=int(input("enter num"))
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# odd

# %%
#ques3
a=int(input("enter number of seconds"))
hr=a//3600
rem=a%3600
m=rem//60
s=rem%60
print("Hours ",hr)
print("Minutes ",m)
print("Seconds ",s)
# Out:
# Hours  0
# Minutes  0
# Seconds  4

# %%
#ques4
p=3600
r=3
t=5
si=(p*r*t)/100
print(si)
# Out:
# 540.0

# %%
#ques5
c=float(input("enter ur cgpa"))
b=int(input("enter backlogs"))
criteria=9
if c>=criteria and b==0:
    print("eligible")
else:
    print("Not eligible")
# Out:
# Not eligible

# %%
#ques6
y=int(input("enter year"))
if (y%400==0) or (y%4==0 and y%100!=0):
    print("leap year")
else:
    print("Not a leap year")

s=input("enter string")
ch=input("enter character ")
if ch in s:
    print("present")
else:
    print("Not present")
# Out:
# Not a leap year
# Not present

# %%
#ques7
l1=[1,2,3]
l2=[1,2,3]
l3=l1
print(l1==l2)
print(l1 is l2)
print(l1==l3)
print(l1 is l3)

a=True
b=False
print("before swapping: ")
print("a=",a)
print("b",b)
a=a^b
b=a^b
a=a^b
print("after swapping ")
print("a=",a)
print("b=",b)
# Out:
# True
# False
# True
# True
# before swapping:
# a= True
# b False
# after swapping
# a= False
# b= True

# %%
#ques8
m=int(input("Enter num"))
r=n<<2
print(r)
# Out:
# 12

# %%
#ques9
n=int(input("enter num "))
if 10<=n<=100:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
#ques10
a=float(input("enter amount"))
d=float(input("enter discount"))
g=float(input("Enter gst"))
b=a-(d*a/100)
b=b+(g*b/100)
print(b)
# Out:
# 372.3654

# %%
#ques11
m1=int(input("enter 1st num"))
m2=int(input("enter 2nd num"))
m3=int(input("enter 3rd num"))
if m1>m2 and m1>m3:
    print(m1)
elif m2>m1 and m2>m3:
    print(m2)
else:
    print(m3)
# Out:
# 89
