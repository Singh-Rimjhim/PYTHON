# %%
import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
# Out:
# NumPy version: 2.5.2
# Pandas version: 3.0.5

# %%
name="Rimjhim Singh"
age="18"
branch="CSE"
college="ABES Engineering College"
year="2nd"
roll_no = 2503201000914

print("Name : ",name)
print("Age: ",age)
print("Branch : ",branch)
print("College : ",college)
print("Year : ",year)
print("Roll no. : ",roll_no)
# Out:
# Name :  Rimjhim Singh
# Age:  18
# Branch :  CSE
# College :  ABES Engineering College
# Year :  2nd
# Roll no. :  2503201000914

# %%
x=10
y=2.43
z="Ritu"
bool=False
print(type(x))
print(type(y))
print(type(z))
print(type(bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=5,10
a,b=b,a
print("a=",a,"b=",b)
# Out:
# a= 10 b= 5

# %%
x,y,z=5,10,15
print(x,y,z)
numbers=[100,120,150]
a,b,c= numbers
print(a, b, c)
# Out:
# 5 10 15
# 100 120 150

# %%
x=100
print("before id: ",x)
x=150
print("after id: ",x)
# Out:
# before id:  100
# after id:  150

# %%
# 6)
l=[1,2,3]
print("Before:",l)
l.append(5)
print("After:",l)
t=(1,2,3)
print("Tuple:",t)
# Out:
# Before: [1, 2, 3]
# After: [1, 2, 3, 5]
# Tuple: (1, 2, 3)

# %%
# 7) 
m=1
def fun():
    global m
    m=12
print("Before fxn calling: ",m)
fun()
print("After fxn calling: ",m)
# Out:
# Before fxn calling:  1
# After fxn calling:  12

# %%
p = 3
print("Before deletion:", p)
del p
#print("After deletion:", p)   # This will raise NameError
# Out:
# Before deletion: 3

# %%
a=input("enter 1st num ")
b=input("enter 2nd num ")
a=int(a)
b=int(b)
print("Addition: ",a+b)
print("Subtraction: ",a-b)
print("Multiplication: ",a*b)
print("Division: ",a/b)
# Out:
# Addition:  7
# Subtraction:  -3
# Multiplication:  10
# Division:  0.4
