# %%
import numpy as np
import pandas as pd

# %%
#ques1
s1='Hello Rimjhim'
s2="Hello Rimjhim"
s3='''Hello Rimjhim'''
print(s1)
print(s2)
print(s3)
# Out:
# Hello Rimjhim
# Hello Rimjhim
# Hello Rimjhim

# %%
#ques2
s="Rimjhim"
print("First character:", s[0])
print("Third character:", s[2])
print("Last character:", s[-1])
print("Second last character:", s[-2])
# Out:
# First character: R
# Third character: m
# Last character: m
# Second last character: i

# %%
#ques3
a="Rimjhim Singh"
reverse=a[::-1]
print(a)
print(reverse)
# Out:
# Rimjhim Singh
# hgniS mihjmiR

# %%
#ques4
a="Rimjhim Singh"
v=0
c=0
for ch in a:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            v=v+1
        else:
            c=c+1
words=len(a.split())
characters=len(a)
print(v)
print(c)
print(words)
print(characters)
# Out:
# 3
# 9
# 2
# 13

# %%
#ques5
m=input("enter string")
if m==m[::-1]:
    print("Palindrome")
else:
    print("isnt palindrome")
# Out:
# Palindrome

# %%
#ques6
m1=input("enter 1st string")
m2=input("enter 2nd string")
if m1==m2:
    print("Equal")
elif m1<m2:
    print(m1,"comes before ",m2)
else:
    print(m2,"comes before",m1)
# Out:
# ritu  comes before  romjhim

# %%
#ques7
p="I m Rimjhim Singh from CSE24"
p1=p.strip()
print(p1)
p2=p1.replace("Rimhim","Ritu")
print(p2)
words=p1.split()
print(words)
result="-".join(words)
print(result)
# Out:
# I m Rimjhim Singh from CSE24
# I m Rimjhim Singh from CSE24
# ['I', 'm', 'Rimjhim', 'Singh', 'from', 'CSE24']
# I-m-Rimjhim-Singh-from-CSE24

# %%
#ques8
n="Rimjhim"
a=18
course="Btech CSE"
print(f"my name is {n}.")
print(f"I m {a} years old.")
print(f"I m pursuing {course}.")
# Out:
# my name is Rimjhim.
# I m 18 years old.
# I m pursuing Btech CSE.

# %%
#ques9
a=10
b=5
print("a > b:", a > b)
print("a < b:", a < b)
print("a == b:", a == b)
print("a != b:", a != b)
print("(a > b) and (a != b):", (a > b) and (a != b))
print("(a < b) or (a != b):", (a < b) or (a != b))
print("not(a > b):", not(a > b))
# Out:
# a > b: True
# a < b: False
# a == b: False
# a != b: True
# (a > b) and (a != b): True
# (a < b) or (a != b): True
# not(a > b): False

# %%
#ques10
num=10
text="Rimjhim"
l=[1,2,3]
d={"name":"Ritu"}

print(bool(num))
print(bool(text))
print(bool(l))
print(bool(d))

print(bool(0))
print(bool(""))
print(bool([]))
print(bool({}))
# Out:
# True
# True
# True
# True
# False
# False
# False
# False

# %%
#ques11
color="blue"
c=input("guess color name")
if color==c.lower():
    print("You won")
else:
    print("You lost")
# Out:
# You lost

# %%
#ques12
def first():
    print("first fxn executed")
    return False
def second():
    print("2nd fxn executed")
    return True

print("using AND")
r=first() and second()
print(r)

print("usinf OR")
# r=first() or second()
r=second() or first()
print(r)
# Out:
# using AND
# first fxn executed
# False
# usinf OR
# 2nd fxn executed
# True
