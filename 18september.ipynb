# %%
import numpy as np
import pandas as pd

# %%
#int
#int 8
#int16
#int32
#array of five zeroses
import numpy as np
list=[3, 2, 4, 6, 1]
x = [1, 2, 3]
a = np.asarray(x)
del list
b = list(a) 

print(a)
print(type(a))
print(type(b))
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>
# <class 'list'>

# %%
country=['india','pakistan','USA','nepal']
pd.Series(country)
# Out:
# 0       india
# 1    pakistan
# 2         USA
# 3       nepal
# dtype: str

# %%
subjects={
    "subjects"  :['maths','english','science','hindi'],
    "marks"     :[67,57,23,32],
    "class"     :[10,12,13,14]
}
numbers=[1,2,3,4]
pd.DataFrame
# Out:
# pandas.DataFrame

# %%
data={"name" :['ranu','rimjhim','ritu','ranjana'],
      "marks" :[100,97,98,99],
          }
pd.DataFrame(data)
# Out:
#       name  marks
# 0     ranu    100
# 1  rimjhim     97
# 2     ritu     98
# 3  ranjana     99
